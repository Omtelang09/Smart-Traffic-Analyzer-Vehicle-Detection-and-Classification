# %%
# Install required packages
# !pip install ultralytics opencv-python supervision

# Import libraries
import cv2
import numpy as np
from ultralytics import YOLO
import supervision as sv
import os

# Load the pretrained YOLOv11 model
model = YOLO("yolo11m.pt")  # Medium model for better accuracy

# Define vehicle classes based on COCO dataset
VEHICLE_CLASSES = {
    2: "car",
    3: "motorcycle",
    5: "bus",
    7: "truck"
}
VEHICLE_CLASS_IDS = list(VEHICLE_CLASSES.keys())

# Set up video input and output paths
input_video_path = "/content/test2.mp4"
output_video_path = "/content/output_video.mp4"

# Initialize video capture
cap = cv2.VideoCapture(input_video_path)
if not cap.isOpened():
    print(f"Error: Could not open video at {input_video_path}. Please check the file path and ensure the video exists.")
    exit()

# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(f"Video properties: Width={frame_width}, Height={frame_height}, FPS={fps}, Total Frames={total_frames}")

# Initialize video writer for output
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))
if not out.isOpened():
    print("Error: Could not initialize VideoWriter. Check codec and output path.")
    cap.release()
    exit()

# Initialize box and label annotators
box_annotator = sv.BoxAnnotator(thickness=2)
label_annotator = sv.LabelAnnotator(text_thickness=2, text_scale=0.5)

# Define the counting lines
LINE_Y_POSITION_YELLOW = int(frame_height * 0.6)  # Yellow line at 60% of frame height
LINE_Y_POSITION_BLUE = LINE_Y_POSITION_YELLOW + 100  # Blue line 100px below yellow line
yellow_line = [(0, LINE_Y_POSITION_YELLOW), (frame_width, LINE_Y_POSITION_YELLOW)]
blue_line = [(0, LINE_Y_POSITION_BLUE), (frame_width, LINE_Y_POSITION_BLUE)]

# Define vertical division
MID_X = frame_width // 2  # Middle of the frame for left/right division

# Initialize vehicle counters
incoming_counts = {cls_name: 0 for cls_name in VEHICLE_CLASSES.values()}  # Left half (yellow -> blue)
outgoing_counts = {cls_name: 0 for cls_name in VEHICLE_CLASSES.values()}  # Right half (blue -> yellow)

# Initialize tracker
tracked_vehicles = {}
vehicle_id_counter = 0
counted_vehicle_ids_incoming = set()  # Track IDs counted for incoming
counted_vehicle_ids_outgoing = set()  # Track IDs counted for outgoing

# Process video frame by frame
frame_idx = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print(f"Reached end of video or failed to read frame at index {frame_idx}.")
        break

    # Perform inference
    results = model(frame, conf=0.5)[0]  # Confidence threshold

    # Convert results to supervision format
    detections = sv.Detections.from_ultralytics(results)

    # Filter for vehicle classes
    vehicle_mask = np.isin(detections.class_id, VEHICLE_CLASS_IDS)
    detections = detections[vehicle_mask]

    # Draw counting lines
    cv2.line(frame, yellow_line[0], yellow_line[1], (0, 255, 255), 2)  # Yellow line
    cv2.line(frame, blue_line[0], blue_line[1], (255, 0, 0), 2)  # Blue line

    # Process detections
    labels = []
    current_vehicles = {}

    for xyxy, confidence, class_id in zip(detections.xyxy, detections.confidence, detections.class_id):
        class_name = VEHICLE_CLASSES[class_id]
        x1, y1, x2, y2 = map(int, xyxy)

        # Calculate center of bounding box
        center_x = (x1 + x2) // 2
        center_y = (y1 + y2) // 2

        # Draw red dot at center
        cv2.circle(frame, (center_x, center_y), 5, (0, 0, 255), -1)

        # Determine direction based on center_x
        direction = "incoming" if center_x < MID_X else "outgoing"

        # Simple tracking: assign ID based on proximity to previous positions
        vehicle_id = None
        min_distance = float('inf')
        for vid, (prev_x, prev_y, _, _, _, _) in tracked_vehicles.items():
            distance = np.sqrt((center_x - prev_x)**2 + (center_y - prev_y)**2)
            if distance < min_distance and distance < 100:  # Threshold for matching
                min_distance = distance
                vehicle_id = vid

        if vehicle_id is None:
            vehicle_id = vehicle_id_counter
            vehicle_id_counter += 1

        # Initialize new vehicle
        if vehicle_id not in tracked_vehicles:
            current_vehicles[vehicle_id] = (center_x, center_y, class_name, False, False, direction)
            label_direction = direction  # Use current direction for new vehicles
        else:
            # Retain previous direction to avoid direction flipping
            prev_x, prev_y, prev_class, crossed_yellow, crossed_blue, prev_direction = tracked_vehicles[vehicle_id]
            current_vehicles[vehicle_id] = (center_x, center_y, class_name, crossed_yellow, crossed_blue, prev_direction)
            label_direction = prev_direction  # Use previous direction for tracked vehicles

        # Check line crossings
        if vehicle_id in tracked_vehicles:
            prev_x, prev_y, prev_class, crossed_yellow, crossed_blue, prev_direction = tracked_vehicles[vehicle_id]

            # Incoming (Left half, Yellow -> Blue)
            if prev_direction == "incoming":
                # Yellow line crossing
                if prev_y <= LINE_Y_POSITION_YELLOW < center_y and not crossed_yellow:
                    current_vehicles[vehicle_id] = (center_x, center_y, class_name, True, crossed_blue, prev_direction)

                # Blue line crossing after yellow
                if prev_y <= LINE_Y_POSITION_BLUE < center_y and crossed_yellow and not crossed_blue:
                    if vehicle_id not in counted_vehicle_ids_incoming:
                        incoming_counts[class_name] += 1
                        counted_vehicle_ids_incoming.add(vehicle_id)
                    current_vehicles[vehicle_id] = (center_x, center_y, class_name, crossed_yellow, True, prev_direction)

            # Outgoing (Right half, Blue -> Yellow)
            elif prev_direction == "outgoing":
                # Blue line crossing (from below to above)
                if center_y <= LINE_Y_POSITION_BLUE < prev_y and not crossed_blue:
                    current_vehicles[vehicle_id] = (center_x, center_y, class_name, crossed_yellow, True, prev_direction)

                # Yellow line crossing after blue
                if center_y <= LINE_Y_POSITION_YELLOW < prev_y and crossed_blue and not crossed_yellow:
                    if vehicle_id not in counted_vehicle_ids_outgoing:
                        outgoing_counts[class_name] += 1
                        counted_vehicle_ids_outgoing.add(vehicle_id)
                    current_vehicles[vehicle_id] = (center_x, center_y, class_name, True, crossed_blue, prev_direction)

        labels.append(f"{class_name} {confidence:.2f} ID:{vehicle_id} {label_direction}")

    # Update tracked vehicles
    tracked_vehicles = current_vehicles

    # Annotate frame with bounding boxes and labels
    annotated_frame = box_annotator.annotate(scene=frame.copy(), detections=detections)
    annotated_frame = label_annotator.annotate(
        scene=annotated_frame, detections=detections, labels=labels
    )

    # Display incoming counts on top left, vertically
    text_x_left = 10
    text_y_start = 30
    line_spacing = 10  # Gap between lines
    max_width_left = 0

    # Draw "Incoming" heading
    heading_text = "Incoming"
    (heading_width, heading_height), heading_baseline = cv2.getTextSize(
        heading_text, cv2.FONT_HERSHEY_SIMPLEX, 0.8, 2
    )
    cv2.rectangle(
        annotated_frame,
        (text_x_left, text_y_start - heading_height - heading_baseline),
        (text_x_left + heading_width, text_y_start + heading_baseline),
        (0, 0, 0),
        -1
    )
    cv2.putText(
        annotated_frame,
        heading_text,
        (text_x_left, text_y_start),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.8,
        (255, 255, 255),
        2
    )
    text_y_start += heading_height + heading_baseline + line_spacing

    # Calculate maximum width for left background rectangles
    for cls in incoming_counts:
        text = f"{cls}: {incoming_counts[cls]}"
        (text_width, _), _ = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, 0.8, 2)
        max_width_left = max(max_width_left, text_width)

    # Draw incoming counts (left)
    for i, cls in enumerate(incoming_counts):
        text = f"{cls}: {incoming_counts[cls]}"
        (text_width, text_height), baseline = cv2.getTextSize(
            text, cv2.FONT_HERSHEY_SIMPLEX, 0.8, 2
        )
        text_y = text_y_start + i * (text_height + baseline + line_spacing)
        bg_top_left = (text_x_left, text_y - text_height - baseline)
        bg_bottom_right = (text_x_left + max_width_left, text_y + baseline)

        # Draw black background
        cv2.rectangle(
            annotated_frame,
            bg_top_left,
            bg_bottom_right,
            (0, 0, 0),
            -1
        )

        # Draw white text
        cv2.putText(
            annotated_frame,
            text,
            (text_x_left, text_y),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.8,
            (255, 255, 255),
            2
        )

    # Display outgoing counts on top right, vertically
    text_x_right = frame_width - max_width_left - 10  # Align right with padding
    text_y_start = 30
    max_width_right = 0

    # Draw "Outgoing" heading
    heading_text = "Outgoing"
    (heading_width, heading_height), heading_baseline = cv2.getTextSize(
        heading_text, cv2.FONT_HERSHEY_SIMPLEX, 0.8, 2
    )
    cv2.rectangle(
        annotated_frame,
        (text_x_right, text_y_start - heading_height - heading_baseline),
        (text_x_right + heading_width, text_y_start + heading_baseline),
        (0, 0, 0),
        -1
    )
    cv2.putText(
        annotated_frame,
        heading_text,
        (text_x_right, text_y_start),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.8,
        (255, 255, 255),
        2
    )
    text_y_start += heading_height + heading_baseline + line_spacing

    # Calculate maximum width for right background rectangles
    for cls in outgoing_counts:
        text = f"{cls}: {outgoing_counts[cls]}"
        (text_width, _), _ = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, 0.8, 2)
        max_width_right = max(max_width_right, text_width)

    # Draw outgoing counts (right)
    for i, cls in enumerate(outgoing_counts):
        text = f"{cls}: {outgoing_counts[cls]}"
        (text_width, text_height), baseline = cv2.getTextSize(
            text, cv2.FONT_HERSHEY_SIMPLEX, 0.8, 2
        )
        text_y = text_y_start + i * (text_height + baseline + line_spacing)
        bg_top_left = (text_x_right, text_y - text_height - baseline)
        bg_bottom_right = (text_x_right + max_width_right, text_y + baseline)

        # Draw black background
        cv2.rectangle(
            annotated_frame,
            bg_top_left,
            bg_bottom_right,
            (0, 0, 0),
            -1
        )

        # Draw white text
        cv2.putText(
            annotated_frame,
            text,
            (text_x_right, text_y),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.8,
            (255, 255, 255),
            2
        )

    # Write frame to output video
    out.write(annotated_frame)

    frame_idx += 1
    print(f"Processed frame {frame_idx}/{total_frames}")

# Release resources
cap.release()
out.release()
print("Video processing completed. Output saved to:", output_video_path)

# Print final counts
print("\nIncoming Vehicle Counts (Left Half, Yellow -> Blue):")
for cls, cnt in incoming_counts.items():
    print(f"{cls}: {cnt}")
print("\nOutgoing Vehicle Counts (Right Half, Blue -> Yellow):")
for cls, cnt in outgoing_counts.items():
    print(f"{cls}: {cnt}")

# Check if output video exists before downloading
if os.path.exists(output_video_path):
    from google.colab import files
    files.download(output_video_path)
else:
    print(f"Error: Output video {output_video_path} not found. Check video processing steps.")
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.148-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Collecting supervision
#   Downloading supervision-0.25.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from supervision) (1.3.2)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from supervision) (0.7.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.148-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 26.9 MB/s eta 0:00:00
# Downloading supervision-0.25.1-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 17.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 125.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 94.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.7 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, supervision, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 supervision-0.25.1 ultralytics-8.3.148 ultralytics-thop-2.0.14
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m.pt to 'yolo11m.pt'...
# 100%|██████████| 38.8M/38.8M [00:00<00:00, 86.0MB/s]
# Streaming output truncated to the last 5000 lines.
# Speed: 3.3ms preprocess, 19.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 385/1631
#
# 0: 384x640 8 cars, 21.6ms
# Speed: 4.4ms preprocess, 21.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 386/1631
#
# 0: 384x640 7 cars, 1 truck, 22.6ms
# Speed: 4.5ms preprocess, 22.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 387/1631
#
# 0: 384x640 8 cars, 19.8ms
# Speed: 3.8ms preprocess, 19.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 388/1631
#
# 0: 384x640 8 cars, 19.7ms
# Speed: 4.2ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 389/1631
#
# 0: 384x640 7 cars, 1 truck, 22.0ms
# Speed: 3.9ms preprocess, 22.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 390/1631
#
# 0: 384x640 8 cars, 1 truck, 19.7ms
# Speed: 3.7ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 391/1631
#
# 0: 384x640 6 cars, 1 truck, 19.7ms
# Speed: 3.7ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 392/1631
#
# 0: 384x640 6 cars, 1 truck, 19.7ms
# Speed: 3.2ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 393/1631
#
# 0: 384x640 8 cars, 19.7ms
# Speed: 4.4ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 394/1631
#
# 0: 384x640 8 cars, 1 truck, 20.1ms
# Speed: 3.4ms preprocess, 20.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 395/1631
#
# 0: 384x640 7 cars, 19.7ms
# Speed: 3.8ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 396/1631
#
# 0: 384x640 7 cars, 19.7ms
# Speed: 3.4ms preprocess, 19.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 397/1631
#
# 0: 384x640 7 cars, 1 truck, 19.7ms
# Speed: 3.8ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 398/1631
#
# 0: 384x640 7 cars, 2 trucks, 19.7ms
# Speed: 3.4ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 399/1631
#
# 0: 384x640 7 cars, 1 truck, 22.1ms
# Speed: 3.5ms preprocess, 22.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 400/1631
#
# 0: 384x640 8 cars, 1 truck, 19.8ms
# Speed: 3.4ms preprocess, 19.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 401/1631
#
# 0: 384x640 7 cars, 1 truck, 19.7ms
# Speed: 3.5ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 402/1631
#
# 0: 384x640 7 cars, 1 truck, 19.8ms
# Speed: 3.3ms preprocess, 19.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 403/1631
#
# 0: 384x640 7 cars, 1 truck, 19.7ms
# Speed: 3.4ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 404/1631
#
# 0: 384x640 5 cars, 2 trucks, 19.7ms
# Speed: 3.3ms preprocess, 19.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 405/1631
#
# 0: 384x640 8 cars, 1 truck, 19.7ms
# Speed: 3.4ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 406/1631
#
# 0: 384x640 7 cars, 1 truck, 22.4ms
# Speed: 4.1ms preprocess, 22.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 407/1631
#
# 0: 384x640 8 cars, 1 truck, 19.7ms
# Speed: 3.3ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 408/1631
#
# 0: 384x640 8 cars, 1 truck, 20.0ms
# Speed: 6.1ms preprocess, 20.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 409/1631
#
# 0: 384x640 9 cars, 1 truck, 20.0ms
# Speed: 6.3ms preprocess, 20.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 410/1631
#
# 0: 384x640 7 cars, 1 truck, 23.2ms
# Speed: 3.4ms preprocess, 23.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 411/1631
#
# 0: 384x640 8 cars, 1 truck, 23.0ms
# Speed: 5.2ms preprocess, 23.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 412/1631
#
# 0: 384x640 9 cars, 1 truck, 20.1ms
# Speed: 5.7ms preprocess, 20.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 413/1631
#
# 0: 384x640 9 cars, 1 truck, 20.1ms
# Speed: 3.6ms preprocess, 20.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 414/1631
#
# 0: 384x640 9 cars, 1 truck, 20.1ms
# Speed: 3.6ms preprocess, 20.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 415/1631
#
# 0: 384x640 9 cars, 1 truck, 20.4ms
# Speed: 6.0ms preprocess, 20.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 416/1631
#
# 0: 384x640 9 cars, 1 truck, 20.4ms
# Speed: 3.3ms preprocess, 20.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 417/1631
#
# 0: 384x640 9 cars, 24.3ms
# Speed: 2.7ms preprocess, 24.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 418/1631
#
# 0: 384x640 8 cars, 20.3ms
# Speed: 3.4ms preprocess, 20.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 419/1631
#
# 0: 384x640 9 cars, 20.4ms
# Speed: 3.8ms preprocess, 20.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 420/1631
#
# 0: 384x640 9 cars, 1 truck, 20.4ms
# Speed: 3.3ms preprocess, 20.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 421/1631
#
# 0: 384x640 10 cars, 1 truck, 20.4ms
# Speed: 4.4ms preprocess, 20.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 422/1631
#
# 0: 384x640 10 cars, 1 truck, 20.7ms
# Speed: 3.3ms preprocess, 20.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 423/1631
#
# 0: 384x640 10 cars, 1 truck, 20.8ms
# Speed: 3.4ms preprocess, 20.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 424/1631
#
# 0: 384x640 10 cars, 1 truck, 21.2ms
# Speed: 3.4ms preprocess, 21.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 425/1631
#
# 0: 384x640 9 cars, 1 truck, 20.8ms
# Speed: 3.6ms preprocess, 20.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 426/1631
#
# 0: 384x640 9 cars, 1 truck, 22.8ms
# Speed: 4.6ms preprocess, 22.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 427/1631
#
# 0: 384x640 7 cars, 1 truck, 23.4ms
# Speed: 3.5ms preprocess, 23.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 428/1631
#
# 0: 384x640 8 cars, 1 truck, 23.3ms
# Speed: 5.1ms preprocess, 23.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 429/1631
#
# 0: 384x640 8 cars, 21.1ms
# Speed: 3.8ms preprocess, 21.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 430/1631
#
# 0: 384x640 8 cars, 20.8ms
# Speed: 3.9ms preprocess, 20.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 431/1631
#
# 0: 384x640 8 cars, 20.7ms
# Speed: 3.8ms preprocess, 20.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 432/1631
#
# 0: 384x640 9 cars, 23.7ms
# Speed: 5.5ms preprocess, 23.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 433/1631
#
# 0: 384x640 9 cars, 1 truck, 21.1ms
# Speed: 3.4ms preprocess, 21.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 434/1631
#
# 0: 384x640 8 cars, 21.1ms
# Speed: 3.8ms preprocess, 21.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 435/1631
#
# 0: 384x640 9 cars, 1 truck, 21.1ms
# Speed: 3.7ms preprocess, 21.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 436/1631
#
# 0: 384x640 8 cars, 1 truck, 20.4ms
# Speed: 3.6ms preprocess, 20.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 437/1631
#
# 0: 384x640 9 cars, 1 truck, 20.4ms
# Speed: 4.4ms preprocess, 20.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 438/1631
#
# 0: 384x640 9 cars, 20.4ms
# Speed: 3.5ms preprocess, 20.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 439/1631
#
# 0: 384x640 9 cars, 20.3ms
# Speed: 3.4ms preprocess, 20.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 440/1631
#
# 0: 384x640 10 cars, 20.3ms
# Speed: 3.4ms preprocess, 20.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 441/1631
#
# 0: 384x640 10 cars, 20.4ms
# Speed: 3.6ms preprocess, 20.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 442/1631
#
# 0: 384x640 10 cars, 20.4ms
# Speed: 3.5ms preprocess, 20.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 443/1631
#
# 0: 384x640 10 cars, 20.4ms
# Speed: 4.6ms preprocess, 20.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 444/1631
#
# 0: 384x640 10 cars, 1 truck, 20.4ms
# Speed: 3.6ms preprocess, 20.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 445/1631
#
# 0: 384x640 10 cars, 1 truck, 20.3ms
# Speed: 7.7ms preprocess, 20.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 446/1631
#
# 0: 384x640 10 cars, 1 truck, 20.3ms
# Speed: 4.5ms preprocess, 20.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 447/1631
#
# 0: 384x640 9 cars, 20.3ms
# Speed: 5.5ms preprocess, 20.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 448/1631
#
# 0: 384x640 9 cars, 22.2ms
# Speed: 4.4ms preprocess, 22.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 449/1631
#
# 0: 384x640 10 cars, 20.4ms
# Speed: 3.8ms preprocess, 20.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 450/1631
#
# 0: 384x640 10 cars, 20.4ms
# Speed: 3.3ms preprocess, 20.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 451/1631
#
# 0: 384x640 9 cars, 1 truck, 20.3ms
# Speed: 3.4ms preprocess, 20.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 452/1631
#
# 0: 384x640 9 cars, 1 truck, 20.3ms
# Speed: 3.4ms preprocess, 20.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 453/1631
#
# 0: 384x640 9 cars, 1 truck, 20.4ms
# Speed: 6.2ms preprocess, 20.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 454/1631
#
# 0: 384x640 10 cars, 19.7ms
# Speed: 3.5ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 455/1631
#
# 0: 384x640 11 cars, 19.7ms
# Speed: 3.4ms preprocess, 19.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 456/1631
#
# 0: 384x640 10 cars, 19.7ms
# Speed: 3.4ms preprocess, 19.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 457/1631
#
# 0: 384x640 10 cars, 19.9ms
# Speed: 3.7ms preprocess, 19.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 458/1631
#
# 0: 384x640 11 cars, 19.7ms
# Speed: 3.3ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 459/1631
#
# 0: 384x640 10 cars, 1 truck, 19.7ms
# Speed: 3.3ms preprocess, 19.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 460/1631
#
# 0: 384x640 9 cars, 2 trucks, 19.7ms
# Speed: 3.6ms preprocess, 19.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 461/1631
#
# 0: 384x640 10 cars, 1 truck, 19.7ms
# Speed: 3.3ms preprocess, 19.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 462/1631
#
# 0: 384x640 10 cars, 1 truck, 19.7ms
# Speed: 4.6ms preprocess, 19.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 463/1631
#
# 0: 384x640 10 cars, 19.7ms
# Speed: 3.6ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 464/1631
#
# 0: 384x640 10 cars, 1 truck, 19.6ms
# Speed: 4.3ms preprocess, 19.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 465/1631
#
# 0: 384x640 9 cars, 19.7ms
# Speed: 3.4ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 466/1631
#
# 0: 384x640 10 cars, 19.7ms
# Speed: 6.6ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 467/1631
#
# 0: 384x640 10 cars, 19.7ms
# Speed: 3.3ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 468/1631
#
# 0: 384x640 10 cars, 1 truck, 19.7ms
# Speed: 6.7ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 469/1631
#
# 0: 384x640 10 cars, 1 truck, 19.7ms
# Speed: 3.3ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 470/1631
#
# 0: 384x640 10 cars, 1 truck, 19.7ms
# Speed: 3.4ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 471/1631
#
# 0: 384x640 10 cars, 1 truck, 19.7ms
# Speed: 3.4ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 472/1631
#
# 0: 384x640 9 cars, 1 truck, 21.0ms
# Speed: 3.3ms preprocess, 21.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 473/1631
#
# 0: 384x640 10 cars, 19.7ms
# Speed: 4.5ms preprocess, 19.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 474/1631
#
# 0: 384x640 10 cars, 19.7ms
# Speed: 3.8ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 475/1631
#
# 0: 384x640 10 cars, 1 truck, 19.7ms
# Speed: 8.1ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 476/1631
#
# 0: 384x640 10 cars, 19.8ms
# Speed: 3.7ms preprocess, 19.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 477/1631
#
# 0: 384x640 8 cars, 1 truck, 19.7ms
# Speed: 3.2ms preprocess, 19.7ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 478/1631
#
# 0: 384x640 9 cars, 1 truck, 19.9ms
# Speed: 3.5ms preprocess, 19.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 479/1631
#
# 0: 384x640 9 cars, 1 truck, 19.7ms
# Speed: 9.4ms preprocess, 19.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 480/1631
#
# 0: 384x640 9 cars, 1 truck, 19.7ms
# Speed: 7.2ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 481/1631
#
# 0: 384x640 10 cars, 1 truck, 20.9ms
# Speed: 3.3ms preprocess, 20.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 482/1631
#
# 0: 384x640 10 cars, 1 truck, 22.9ms
# Speed: 2.8ms preprocess, 22.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 483/1631
#
# 0: 384x640 10 cars, 1 truck, 19.8ms
# Speed: 3.4ms preprocess, 19.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 484/1631
#
# 0: 384x640 10 cars, 1 truck, 19.7ms
# Speed: 3.3ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 485/1631
#
# 0: 384x640 9 cars, 20.3ms
# Speed: 3.3ms preprocess, 20.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 486/1631
#
# 0: 384x640 10 cars, 1 truck, 20.3ms
# Speed: 4.1ms preprocess, 20.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 487/1631
#
# 0: 384x640 9 cars, 1 truck, 20.3ms
# Speed: 3.3ms preprocess, 20.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 488/1631
#
# 0: 384x640 9 cars, 1 truck, 20.3ms
# Speed: 3.3ms preprocess, 20.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 489/1631
#
# 0: 384x640 10 cars, 1 truck, 20.3ms
# Speed: 3.6ms preprocess, 20.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 490/1631
#
# 0: 384x640 10 cars, 1 truck, 20.4ms
# Speed: 3.3ms preprocess, 20.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 491/1631
#
# 0: 384x640 10 cars, 1 truck, 20.4ms
# Speed: 3.9ms preprocess, 20.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 492/1631
#
# 0: 384x640 10 cars, 1 truck, 20.6ms
# Speed: 3.3ms preprocess, 20.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 493/1631
#
# 0: 384x640 9 cars, 1 truck, 20.7ms
# Speed: 5.8ms preprocess, 20.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 494/1631
#
# 0: 384x640 10 cars, 1 truck, 20.7ms
# Speed: 5.7ms preprocess, 20.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 495/1631
#
# 0: 384x640 10 cars, 1 truck, 20.7ms
# Speed: 3.3ms preprocess, 20.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 496/1631
#
# 0: 384x640 9 cars, 1 truck, 20.4ms
# Speed: 3.8ms preprocess, 20.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 497/1631
#
# 0: 384x640 9 cars, 1 truck, 20.0ms
# Speed: 4.4ms preprocess, 20.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 498/1631
#
# 0: 384x640 9 cars, 20.1ms
# Speed: 3.2ms preprocess, 20.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 499/1631
#
# 0: 384x640 10 cars, 20.0ms
# Speed: 3.5ms preprocess, 20.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 500/1631
#
# 0: 384x640 10 cars, 20.0ms
# Speed: 3.9ms preprocess, 20.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 501/1631
#
# 0: 384x640 11 cars, 20.1ms
# Speed: 3.7ms preprocess, 20.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 502/1631
#
# 0: 384x640 10 cars, 1 truck, 20.0ms
# Speed: 3.5ms preprocess, 20.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 503/1631
#
# 0: 384x640 10 cars, 1 truck, 20.0ms
# Speed: 3.4ms preprocess, 20.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 504/1631
#
# 0: 384x640 10 cars, 20.0ms
# Speed: 4.0ms preprocess, 20.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 505/1631
#
# 0: 384x640 10 cars, 1 truck, 20.0ms
# Speed: 3.3ms preprocess, 20.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 506/1631
#
# 0: 384x640 10 cars, 20.7ms
# Speed: 4.7ms preprocess, 20.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 507/1631
#
# 0: 384x640 10 cars, 20.8ms
# Speed: 3.8ms preprocess, 20.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 508/1631
#
# 0: 384x640 10 cars, 20.0ms
# Speed: 6.1ms preprocess, 20.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 509/1631
#
# 0: 384x640 11 cars, 20.1ms
# Speed: 3.4ms preprocess, 20.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 510/1631
#
# 0: 384x640 12 cars, 23.0ms
# Speed: 3.2ms preprocess, 23.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 511/1631
#
# 0: 384x640 10 cars, 21.7ms
# Speed: 6.0ms preprocess, 21.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 512/1631
#
# 0: 384x640 12 cars, 29.0ms
# Speed: 3.3ms preprocess, 29.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 513/1631
#
# 0: 384x640 11 cars, 1 truck, 21.9ms
# Speed: 4.8ms preprocess, 21.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 514/1631
#
# 0: 384x640 12 cars, 1 truck, 20.0ms
# Speed: 3.2ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 515/1631
#
# 0: 384x640 11 cars, 1 truck, 20.9ms
# Speed: 3.3ms preprocess, 20.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 516/1631
#
# 0: 384x640 10 cars, 1 truck, 20.0ms
# Speed: 3.1ms preprocess, 20.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 517/1631
#
# 0: 384x640 10 cars, 1 truck, 20.8ms
# Speed: 7.1ms preprocess, 20.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 518/1631
#
# 0: 384x640 12 cars, 1 truck, 23.5ms
# Speed: 5.0ms preprocess, 23.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 519/1631
#
# 0: 384x640 12 cars, 1 truck, 21.2ms
# Speed: 3.3ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 520/1631
#
# 0: 384x640 12 cars, 22.8ms
# Speed: 3.2ms preprocess, 22.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 521/1631
#
# 0: 384x640 12 cars, 21.3ms
# Speed: 3.4ms preprocess, 21.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 522/1631
#
# 0: 384x640 12 cars, 21.1ms
# Speed: 3.4ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 523/1631
#
# 0: 384x640 12 cars, 23.3ms
# Speed: 9.0ms preprocess, 23.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 524/1631
#
# 0: 384x640 12 cars, 23.3ms
# Speed: 7.7ms preprocess, 23.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 525/1631
#
# 0: 384x640 12 cars, 23.9ms
# Speed: 3.5ms preprocess, 23.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 526/1631
#
# 0: 384x640 12 cars, 24.3ms
# Speed: 7.4ms preprocess, 24.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 527/1631
#
# 0: 384x640 11 cars, 24.3ms
# Speed: 3.5ms preprocess, 24.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 528/1631
#
# 0: 384x640 11 cars, 25.4ms
# Speed: 6.4ms preprocess, 25.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 529/1631
#
# 0: 384x640 11 cars, 24.3ms
# Speed: 3.3ms preprocess, 24.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 530/1631
#
# 0: 384x640 9 cars, 26.0ms
# Speed: 3.9ms preprocess, 26.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 531/1631
#
# 0: 384x640 10 cars, 24.3ms
# Speed: 3.1ms preprocess, 24.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 532/1631
#
# 0: 384x640 10 cars, 26.5ms
# Speed: 3.4ms preprocess, 26.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 533/1631
#
# 0: 384x640 10 cars, 24.2ms
# Speed: 3.2ms preprocess, 24.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 534/1631
#
# 0: 384x640 11 cars, 24.3ms
# Speed: 3.3ms preprocess, 24.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 535/1631
#
# 0: 384x640 9 cars, 24.4ms
# Speed: 3.7ms preprocess, 24.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 536/1631
#
# 0: 384x640 10 cars, 26.4ms
# Speed: 3.3ms preprocess, 26.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 537/1631
#
# 0: 384x640 10 cars, 25.3ms
# Speed: 3.1ms preprocess, 25.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 538/1631
#
# 0: 384x640 11 cars, 24.3ms
# Speed: 3.3ms preprocess, 24.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 539/1631
#
# 0: 384x640 10 cars, 24.3ms
# Speed: 11.0ms preprocess, 24.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 540/1631
#
# 0: 384x640 9 cars, 38.6ms
# Speed: 3.7ms preprocess, 38.6ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 541/1631
#
# 0: 384x640 10 cars, 24.3ms
# Speed: 6.6ms preprocess, 24.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 542/1631
#
# 0: 384x640 9 cars, 24.6ms
# Speed: 6.4ms preprocess, 24.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 543/1631
#
# 0: 384x640 9 cars, 28.8ms
# Speed: 3.3ms preprocess, 28.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 544/1631
#
# 0: 384x640 9 cars, 24.3ms
# Speed: 3.2ms preprocess, 24.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 545/1631
#
# 0: 384x640 9 cars, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 546/1631
#
# 0: 384x640 8 cars, 24.3ms
# Speed: 3.2ms preprocess, 24.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 547/1631
#
# 0: 384x640 10 cars, 24.3ms
# Speed: 3.3ms preprocess, 24.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 548/1631
#
# 0: 384x640 9 cars, 24.3ms
# Speed: 4.0ms preprocess, 24.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 549/1631
#
# 0: 384x640 9 cars, 27.8ms
# Speed: 3.3ms preprocess, 27.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 550/1631
#
# 0: 384x640 9 cars, 21.9ms
# Speed: 3.4ms preprocess, 21.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 551/1631
#
# 0: 384x640 8 cars, 21.9ms
# Speed: 3.3ms preprocess, 21.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 552/1631
#
# 0: 384x640 9 cars, 22.0ms
# Speed: 3.2ms preprocess, 22.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 553/1631
#
# 0: 384x640 9 cars, 21.9ms
# Speed: 3.0ms preprocess, 21.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 554/1631
#
# 0: 384x640 9 cars, 21.9ms
# Speed: 3.0ms preprocess, 21.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 555/1631
#
# 0: 384x640 8 cars, 21.9ms
# Speed: 3.0ms preprocess, 21.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 556/1631
#
# 0: 384x640 9 cars, 21.9ms
# Speed: 3.2ms preprocess, 21.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 557/1631
#
# 0: 384x640 9 cars, 22.7ms
# Speed: 3.4ms preprocess, 22.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 558/1631
#
# 0: 384x640 8 cars, 21.9ms
# Speed: 3.3ms preprocess, 21.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 559/1631
#
# 0: 384x640 9 cars, 21.9ms
# Speed: 5.8ms preprocess, 21.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 560/1631
#
# 0: 384x640 9 cars, 21.9ms
# Speed: 4.8ms preprocess, 21.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 561/1631
#
# 0: 384x640 10 cars, 21.8ms
# Speed: 3.3ms preprocess, 21.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 562/1631
#
# 0: 384x640 9 cars, 21.9ms
# Speed: 3.3ms preprocess, 21.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 563/1631
#
# 0: 384x640 10 cars, 21.9ms
# Speed: 3.5ms preprocess, 21.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 564/1631
#
# 0: 384x640 9 cars, 21.8ms
# Speed: 3.2ms preprocess, 21.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 565/1631
#
# 0: 384x640 9 cars, 21.9ms
# Speed: 3.3ms preprocess, 21.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 566/1631
#
# 0: 384x640 8 cars, 21.9ms
# Speed: 3.3ms preprocess, 21.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 567/1631
#
# 0: 384x640 8 cars, 21.9ms
# Speed: 6.9ms preprocess, 21.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 568/1631
#
# 0: 384x640 9 cars, 21.9ms
# Speed: 4.0ms preprocess, 21.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 569/1631
#
# 0: 384x640 8 cars, 25.2ms
# Speed: 4.6ms preprocess, 25.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 570/1631
#
# 0: 384x640 9 cars, 21.9ms
# Speed: 3.2ms preprocess, 21.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 571/1631
#
# 0: 384x640 8 cars, 20.8ms
# Speed: 5.7ms preprocess, 20.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 572/1631
#
# 0: 384x640 8 cars, 24.7ms
# Speed: 3.2ms preprocess, 24.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 573/1631
#
# 0: 384x640 8 cars, 22.2ms
# Speed: 3.8ms preprocess, 22.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 574/1631
#
# 0: 384x640 9 cars, 20.9ms
# Speed: 3.6ms preprocess, 20.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 575/1631
#
# 0: 384x640 9 cars, 20.7ms
# Speed: 7.6ms preprocess, 20.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 576/1631
#
# 0: 384x640 9 cars, 22.4ms
# Speed: 3.3ms preprocess, 22.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 577/1631
#
# 0: 384x640 9 cars, 20.7ms
# Speed: 3.9ms preprocess, 20.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 578/1631
#
# 0: 384x640 9 cars, 20.7ms
# Speed: 4.4ms preprocess, 20.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 579/1631
#
# 0: 384x640 9 cars, 21.3ms
# Speed: 3.1ms preprocess, 21.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 580/1631
#
# 0: 384x640 9 cars, 20.7ms
# Speed: 3.3ms preprocess, 20.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 581/1631
#
# 0: 384x640 10 cars, 20.7ms
# Speed: 3.3ms preprocess, 20.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 582/1631
#
# 0: 384x640 9 cars, 20.7ms
# Speed: 3.3ms preprocess, 20.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 583/1631
#
# 0: 384x640 9 cars, 20.8ms
# Speed: 3.8ms preprocess, 20.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 584/1631
#
# 0: 384x640 8 cars, 20.7ms
# Speed: 3.3ms preprocess, 20.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 585/1631
#
# 0: 384x640 10 cars, 20.7ms
# Speed: 3.2ms preprocess, 20.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 586/1631
#
# 0: 384x640 10 cars, 20.7ms
# Speed: 3.2ms preprocess, 20.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 587/1631
#
# 0: 384x640 10 cars, 20.7ms
# Speed: 4.1ms preprocess, 20.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 588/1631
#
# 0: 384x640 8 cars, 20.7ms
# Speed: 3.3ms preprocess, 20.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 589/1631
#
# 0: 384x640 8 cars, 19.6ms
# Speed: 3.5ms preprocess, 19.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 590/1631
#
# 0: 384x640 8 cars, 19.7ms
# Speed: 3.4ms preprocess, 19.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 591/1631
#
# 0: 384x640 9 cars, 23.2ms
# Speed: 3.3ms preprocess, 23.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 592/1631
#
# 0: 384x640 9 cars, 19.7ms
# Speed: 4.8ms preprocess, 19.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 593/1631
#
# 0: 384x640 8 cars, 19.7ms
# Speed: 3.7ms preprocess, 19.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 594/1631
#
# 0: 384x640 9 cars, 19.7ms
# Speed: 3.4ms preprocess, 19.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 595/1631
#
# 0: 384x640 8 cars, 19.7ms
# Speed: 3.4ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 596/1631
#
# 0: 384x640 8 cars, 19.7ms
# Speed: 4.5ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 597/1631
#
# 0: 384x640 8 cars, 19.7ms
# Speed: 3.8ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 598/1631
#
# 0: 384x640 9 cars, 20.1ms
# Speed: 4.2ms preprocess, 20.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 599/1631
#
# 0: 384x640 8 cars, 19.7ms
# Speed: 7.3ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 600/1631
#
# 0: 384x640 9 cars, 19.7ms
# Speed: 7.8ms preprocess, 19.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 601/1631
#
# 0: 384x640 9 cars, 20.1ms
# Speed: 3.4ms preprocess, 20.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 602/1631
#
# 0: 384x640 8 cars, 19.7ms
# Speed: 5.0ms preprocess, 19.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 603/1631
#
# 0: 384x640 8 cars, 22.7ms
# Speed: 4.8ms preprocess, 22.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 604/1631
#
# 0: 384x640 8 cars, 19.7ms
# Speed: 5.7ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 605/1631
#
# 0: 384x640 5 cars, 19.8ms
# Speed: 3.3ms preprocess, 19.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 606/1631
#
# 0: 384x640 7 cars, 19.7ms
# Speed: 3.3ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 607/1631
#
# 0: 384x640 8 cars, 19.7ms
# Speed: 3.4ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 608/1631
#
# 0: 384x640 7 cars, 19.7ms
# Speed: 3.4ms preprocess, 19.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 609/1631
#
# 0: 384x640 9 cars, 22.5ms
# Speed: 4.5ms preprocess, 22.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 610/1631
#
# 0: 384x640 10 cars, 23.4ms
# Speed: 3.4ms preprocess, 23.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 611/1631
#
# 0: 384x640 9 cars, 25.8ms
# Speed: 4.0ms preprocess, 25.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 612/1631
#
# 0: 384x640 10 cars, 19.7ms
# Speed: 3.4ms preprocess, 19.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 613/1631
#
# 0: 384x640 9 cars, 24.2ms
# Speed: 3.5ms preprocess, 24.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 614/1631
#
# 0: 384x640 11 cars, 20.0ms
# Speed: 3.5ms preprocess, 20.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 615/1631
#
# 0: 384x640 12 cars, 19.7ms
# Speed: 3.6ms preprocess, 19.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 616/1631
#
# 0: 384x640 10 cars, 19.7ms
# ...
# Processed frame 1528/1631
#
# 0: 384x640 10 cars, 1 truck, 22.8ms
# Speed: 3.3ms preprocess, 22.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1529/1631
#
# 0: 384x640 9 cars, 1 truck, 23.2ms
# Speed: 3.1ms preprocess, 23.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1530/1631
#
# 0: 384x640 9 cars, 1 truck, 23.3ms
# Speed: 3.2ms preprocess, 23.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1531/1631
#
# 0: 384x640 8 cars, 1 truck, 23.3ms
# Speed: 5.5ms preprocess, 23.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1532/1631
#
# 0: 384x640 8 cars, 1 truck, 23.2ms
# Speed: 4.4ms preprocess, 23.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1533/1631
#
# 0: 384x640 9 cars, 1 truck, 23.2ms
# Speed: 5.4ms preprocess, 23.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1534/1631
#
# 0: 384x640 10 cars, 23.3ms
# Speed: 3.4ms preprocess, 23.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1535/1631
#
# 0: 384x640 9 cars, 1 truck, 23.3ms
# Speed: 3.3ms preprocess, 23.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1536/1631
#
# 0: 384x640 9 cars, 24.4ms
# Speed: 4.2ms preprocess, 24.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1537/1631
#
# 0: 384x640 10 cars, 2 trucks, 24.1ms
# Speed: 4.3ms preprocess, 24.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1538/1631
#
# 0: 384x640 9 cars, 2 trucks, 23.6ms
# Speed: 3.2ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1539/1631
#
# 0: 384x640 10 cars, 23.7ms
# Speed: 3.3ms preprocess, 23.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1540/1631
#
# 0: 384x640 9 cars, 23.8ms
# Speed: 8.3ms preprocess, 23.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1541/1631
#
# 0: 384x640 10 cars, 24.6ms
# Speed: 4.5ms preprocess, 24.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1542/1631
#
# 0: 384x640 10 cars, 23.8ms
# Speed: 3.4ms preprocess, 23.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1543/1631
#
# 0: 384x640 10 cars, 23.7ms
# Speed: 3.6ms preprocess, 23.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1544/1631
#
# 0: 384x640 10 cars, 24.1ms
# Speed: 4.8ms preprocess, 24.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1545/1631
#
# 0: 384x640 9 cars, 23.8ms
# Speed: 8.5ms preprocess, 23.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1546/1631
#
# 0: 384x640 9 cars, 25.8ms
# Speed: 7.7ms preprocess, 25.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1547/1631
#
# 0: 384x640 9 cars, 25.5ms
# Speed: 3.3ms preprocess, 25.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1548/1631
#
# 0: 384x640 8 cars, 24.3ms
# Speed: 3.4ms preprocess, 24.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1549/1631
#
# 0: 384x640 7 cars, 24.3ms
# Speed: 5.0ms preprocess, 24.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1550/1631
#
# 0: 384x640 8 cars, 25.4ms
# Speed: 3.4ms preprocess, 25.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1551/1631
#
# 0: 384x640 8 cars, 27.3ms
# Speed: 4.3ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1552/1631
#
# 0: 384x640 8 cars, 24.3ms
# Speed: 5.9ms preprocess, 24.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1553/1631
#
# 0: 384x640 6 cars, 24.3ms
# Speed: 5.1ms preprocess, 24.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1554/1631
#
# 0: 384x640 8 cars, 24.3ms
# Speed: 7.0ms preprocess, 24.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1555/1631
#
# 0: 384x640 8 cars, 24.3ms
# Speed: 4.8ms preprocess, 24.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1556/1631
#
# 0: 384x640 8 cars, 24.3ms
# Speed: 4.4ms preprocess, 24.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1557/1631
#
# 0: 384x640 8 cars, 25.6ms
# Speed: 3.2ms preprocess, 25.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1558/1631
#
# 0: 384x640 9 cars, 26.0ms
# Speed: 3.3ms preprocess, 26.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1559/1631
#
# 0: 384x640 9 cars, 24.8ms
# Speed: 3.4ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1560/1631
#
# 0: 384x640 8 cars, 24.3ms
# Speed: 4.6ms preprocess, 24.3ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1561/1631
#
# 0: 384x640 6 cars, 26.5ms
# Speed: 3.3ms preprocess, 26.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1562/1631
#
# 0: 384x640 7 cars, 27.3ms
# Speed: 3.2ms preprocess, 27.3ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1563/1631
#
# 0: 384x640 7 cars, 24.3ms
# Speed: 6.0ms preprocess, 24.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1564/1631
#
# 0: 384x640 7 cars, 24.4ms
# Speed: 3.4ms preprocess, 24.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1565/1631
#
# 0: 384x640 8 cars, 24.3ms
# Speed: 8.2ms preprocess, 24.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1566/1631
#
# 0: 384x640 8 cars, 24.3ms
# Speed: 6.3ms preprocess, 24.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1567/1631
#
# 0: 384x640 8 cars, 24.3ms
# Speed: 3.8ms preprocess, 24.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1568/1631
#
# 0: 384x640 9 cars, 24.3ms
# Speed: 4.5ms preprocess, 24.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1569/1631
#
# 0: 384x640 9 cars, 24.3ms
# Speed: 6.2ms preprocess, 24.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1570/1631
#
# 0: 384x640 10 cars, 24.5ms
# Speed: 3.5ms preprocess, 24.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1571/1631
#
# 0: 384x640 9 cars, 24.9ms
# Speed: 8.4ms preprocess, 24.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1572/1631
#
# 0: 384x640 9 cars, 1 truck, 25.2ms
# Speed: 3.2ms preprocess, 25.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1573/1631
#
# 0: 384x640 9 cars, 1 truck, 24.7ms
# Speed: 8.4ms preprocess, 24.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1574/1631
#
# 0: 384x640 8 cars, 1 truck, 28.0ms
# Speed: 3.3ms preprocess, 28.0ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1575/1631
#
# 0: 384x640 7 cars, 1 truck, 25.7ms
# Speed: 4.1ms preprocess, 25.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1576/1631
#
# 0: 384x640 8 cars, 24.2ms
# Speed: 3.3ms preprocess, 24.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1577/1631
#
# 0: 384x640 8 cars, 38.8ms
# Speed: 3.2ms preprocess, 38.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1578/1631
#
# 0: 384x640 9 cars, 24.3ms
# Speed: 3.4ms preprocess, 24.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1579/1631
#
# 0: 384x640 7 cars, 24.2ms
# Speed: 3.4ms preprocess, 24.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1580/1631
#
# 0: 384x640 7 cars, 24.3ms
# Speed: 3.2ms preprocess, 24.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1581/1631
#
# 0: 384x640 8 cars, 24.2ms
# Speed: 3.2ms preprocess, 24.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1582/1631
#
# 0: 384x640 8 cars, 24.3ms
# Speed: 3.2ms preprocess, 24.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1583/1631
#
# 0: 384x640 7 cars, 25.0ms
# Speed: 3.3ms preprocess, 25.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1584/1631
#
# 0: 384x640 8 cars, 24.3ms
# Speed: 3.4ms preprocess, 24.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1585/1631
#
# 0: 384x640 8 cars, 24.3ms
# Speed: 3.7ms preprocess, 24.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1586/1631
#
# 0: 384x640 8 cars, 24.3ms
# Speed: 3.2ms preprocess, 24.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1587/1631
#
# 0: 384x640 8 cars, 24.3ms
# Speed: 6.6ms preprocess, 24.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1588/1631
#
# 0: 384x640 8 cars, 24.3ms
# Speed: 3.4ms preprocess, 24.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1589/1631
#
# 0: 384x640 9 cars, 23.8ms
# Speed: 3.5ms preprocess, 23.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1590/1631
#
# 0: 384x640 10 cars, 22.5ms
# Speed: 3.4ms preprocess, 22.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1591/1631
#
# 0: 384x640 10 cars, 22.8ms
# Speed: 3.3ms preprocess, 22.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1592/1631
#
# 0: 384x640 9 cars, 22.4ms
# Speed: 3.2ms preprocess, 22.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1593/1631
#
# 0: 384x640 9 cars, 22.9ms
# Speed: 3.4ms preprocess, 22.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1594/1631
#
# 0: 384x640 8 cars, 22.3ms
# Speed: 3.5ms preprocess, 22.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1595/1631
#
# 0: 384x640 8 cars, 22.4ms
# Speed: 3.7ms preprocess, 22.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1596/1631
#
# 0: 384x640 8 cars, 22.3ms
# Speed: 3.4ms preprocess, 22.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1597/1631
#
# 0: 384x640 8 cars, 22.3ms
# Speed: 7.0ms preprocess, 22.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1598/1631
#
# 0: 384x640 8 cars, 22.9ms
# Speed: 3.5ms preprocess, 22.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1599/1631
#
# 0: 384x640 7 cars, 22.3ms
# Speed: 3.6ms preprocess, 22.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1600/1631
#
# 0: 384x640 7 cars, 22.3ms
# Speed: 3.7ms preprocess, 22.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1601/1631
#
# 0: 384x640 5 cars, 22.3ms
# Speed: 3.2ms preprocess, 22.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1602/1631
#
# 0: 384x640 6 cars, 22.4ms
# Speed: 3.6ms preprocess, 22.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1603/1631
#
# 0: 384x640 6 cars, 22.3ms
# Speed: 3.9ms preprocess, 22.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1604/1631
#
# 0: 384x640 6 cars, 22.3ms
# Speed: 3.3ms preprocess, 22.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1605/1631
#
# 0: 384x640 7 cars, 22.3ms
# Speed: 3.4ms preprocess, 22.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1606/1631
#
# 0: 384x640 6 cars, 21.5ms
# Speed: 3.4ms preprocess, 21.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1607/1631
#
# 0: 384x640 6 cars, 21.5ms
# Speed: 4.0ms preprocess, 21.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1608/1631
#
# 0: 384x640 6 cars, 21.5ms
# Speed: 3.3ms preprocess, 21.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1609/1631
#
# 0: 384x640 7 cars, 1 bus, 21.5ms
# Speed: 4.5ms preprocess, 21.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1610/1631
#
# 0: 384x640 6 cars, 21.5ms
# Speed: 4.8ms preprocess, 21.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1611/1631
#
# 0: 384x640 7 cars, 1 bus, 21.5ms
# Speed: 3.3ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1612/1631
#
# 0: 384x640 6 cars, 21.5ms
# Speed: 3.3ms preprocess, 21.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1613/1631
#
# 0: 384x640 6 cars, 23.7ms
# Speed: 4.4ms preprocess, 23.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1614/1631
#
# 0: 384x640 7 cars, 20.1ms
# Speed: 3.7ms preprocess, 20.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1615/1631
#
# 0: 384x640 8 cars, 20.0ms
# Speed: 3.5ms preprocess, 20.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1616/1631
#
# 0: 384x640 7 cars, 20.0ms
# Speed: 3.3ms preprocess, 20.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1617/1631
#
# 0: 384x640 7 cars, 20.0ms
# Speed: 3.1ms preprocess, 20.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1618/1631
#
# 0: 384x640 6 cars, 21.1ms
# Speed: 3.4ms preprocess, 21.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1619/1631
#
# 0: 384x640 6 cars, 20.1ms
# Speed: 4.6ms preprocess, 20.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1620/1631
#
# 0: 384x640 7 cars, 20.1ms
# Speed: 3.6ms preprocess, 20.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1621/1631
#
# 0: 384x640 5 cars, 21.8ms
# Speed: 4.4ms preprocess, 21.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1622/1631
#
# 0: 384x640 7 cars, 24.9ms
# Speed: 5.0ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1623/1631
#
# 0: 384x640 7 cars, 20.0ms
# Speed: 7.4ms preprocess, 20.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1624/1631
#
# 0: 384x640 6 cars, 20.0ms
# Speed: 4.3ms preprocess, 20.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1625/1631
#
# 0: 384x640 5 cars, 20.0ms
# Speed: 4.4ms preprocess, 20.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1626/1631
#
# 0: 384x640 5 cars, 21.9ms
# Speed: 3.3ms preprocess, 21.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1627/1631
#
# 0: 384x640 5 cars, 20.0ms
# Speed: 4.1ms preprocess, 20.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1628/1631
#
# 0: 384x640 6 cars, 20.0ms
# Speed: 3.3ms preprocess, 20.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1629/1631
#
# 0: 384x640 7 cars, 22.8ms
# Speed: 6.5ms preprocess, 22.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1630/1631
#
# 0: 384x640 6 cars, 20.0ms
# Speed: 3.3ms preprocess, 20.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1631/1631
# Reached end of video or failed to read frame at index 1631.
# Video processing completed. Output saved to: /content/output_video.mp4
#
# Incoming Vehicle Counts (Left Half, Yellow -> Blue):
# car: 3
# motorcycle: 0
# bus: 0
# truck: 0
#
# Outgoing Vehicle Counts (Right Half, Blue -> Yellow):
# car: 33
# motorcycle: 0
# bus: 0
# truck: 1
